# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.Ram = df.Ram.str.replace('GB', '')

# %%
df.Weight = df.Weight.str.replace('kg','')

# %%
df.Ram = df.Ram.astype('int32')
df.Weight = df.Weight.astype('float32')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
sns.histplot(df.Price, kde=True)
plt.show()

# %%
df.Company.value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df.Company, y=df.Price, palette='viridis')
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# C:\Users\Amir Khan\AppData\Local\Temp\ipykernel_36124\1714245678.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df.Company, y=df.Price, palette='viridis')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.TypeName.value_counts().plot(kind='pie', autopct='%0.1f%%', colors =['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x=df.TypeName, y=df.Price, palette='viridis')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.histplot(df.Inches, kde=True)
plt.show()

# %%
sns.scatterplot(x=df.Inches, y=df.Price)
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['Touchscreen'] = df.ScreenResolution.apply(lambda x : 1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches                  ScreenResolution  \
# 1163  Lenovo   Notebook    15.6                          1366x768
# 888     Acer    Netbook    11.6                IPS Panel 1366x768
# 251     Asus     Gaming    17.3                 Full HD 1920x1080
# 242     Asus   Notebook    17.3                 Full HD 1920x1080
# 1226    Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                                        Cpu  Ram                Memory  \
# 1163            Intel Core i3 6006U 2.0GHz    8               1TB HDD
# 888   Intel Celeron Dual Core N3060 1.6GHz    4    32GB Flash Storage
# 251            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 242             Intel Core i7 7500U 2.7GHz    8  128GB SSD +  1TB HDD
# 1226            Intel Core i7 7500U 2.7GHz    8             256GB SSD
#
#                           Gpu       OpSys  Weight     Price  Touchscreen
# 1163    Intel HD Graphics 520  Windows 10    2.20  24455.52            0
# 888     Intel HD Graphics 400   Chrome OS    1.25  15824.16            0
# 251   Nvidia GeForce GTX 980M  Windows 10    4.30  95850.72            0
# 242   Nvidia GeForce GTX 950M       No OS    2.69  47365.92            0
# 1226    Intel HD Graphics 620  Windows 10    1.29  78694.56            1

# %%
ax = df.Touchscreen.value_counts().plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %%
sns.barplot(x=df.Touchscreen, y=df.Price)
plt.show()

# %%
df['Ips'] = df.ScreenResolution.apply(lambda x : 1 if 'IPS' in x else 0)

# %%
df.sample(5)
# Out:
#      Company     TypeName  Inches             ScreenResolution  \
# 624       HP     Notebook    15.6                     1366x768
# 387     Dell  Workstation    15.6            Full HD 1920x1080
# 969   Lenovo     Notebook    15.6            Full HD 1920x1080
# 1289    Asus    Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 31      Asus     Notebook    14.0                     1366x768
#
#                               Cpu  Ram              Memory  \
# 624    Intel Core i5 6200U 2.3GHz    4           500GB HDD
# 387   Intel Core i5 6440HQ 2.6GHz    8           500GB HDD
# 969    Intel Core i5 7200U 2.5GHz    6           256GB SSD
# 1289     Intel Core M 6Y30 0.9GHz    8           512GB SSD
# 31    AMD E-Series E2-6110 1.5GHz    2  32GB Flash Storage
#
#                         Gpu       OpSys  Weight     Price  Touchscreen  Ips
# 624   Intel HD Graphics 520   Windows 7    1.88  49656.96            0    0
# 387      AMD FirePro W5130M  Windows 10    2.23  72940.32            0    0
# 969    Nvidia GeForce 920MX  Windows 10    2.40  37029.60            0    0
# 1289  Intel HD Graphics 515  Windows 10    1.20  38841.12            0    1
# 31            AMD Radeon R2  Windows 10    1.65  10602.72            0    0

# %%
ax = df.Ips.value_counts().plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %%
sns.barplot(x=df.Ips, y=df.Price)
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1

# %%
new = df.ScreenResolution.str.split('x', expand=True, n=1)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#                            X_res Y_res
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
df.X_res = df.X_res.str[-4:]

# %%
df.sample(20)
# Out:
#        Company            TypeName  Inches             ScreenResolution  \
# 181       Dell           Ultrabook    13.3            Full HD 1920x1080
# 246         HP            Notebook    15.6         Touchscreen 1366x768
# 1159        HP  2 in 1 Convertible    13.3        Touchscreen 2560x1440
# 764       Dell            Notebook    13.3                     1366x768
# 827       Dell            Notebook    14.0                     1366x768
# 76      Lenovo            Notebook    15.6            Full HD 1920x1080
# 349       Dell           Ultrabook    15.6            Full HD 1920x1080
# 533   Mediacom            Notebook    13.3  IPS Panel Full HD 1920x1080
# 1236        HP           Ultrabook    14.0                    2560x1440
# 148        MSI              Gaming    17.3            Full HD 1920x1080
# 1292      Dell            Notebook    15.6                     1366x768
# 99          HP              Gaming    15.6  IPS Panel Full HD 1920x1080
# 139         HP            Notebook    13.3  IPS Panel Full HD 1920x1080
# 810         HP              Gaming    17.3  IPS Panel Full HD 1920x1080
# 1165      Dell              Gaming    15.6        4K Ultra HD 3840x2160
# 860     Lenovo            Notebook    15.6  IPS Panel Full HD 1920x1080
# 1283      Asus            Notebook    15.6                     1366x768
# 478       Dell            Notebook    15.6            Full HD 1920x1080
# 1168        HP            Notebook    14.0                     1366x768
# 1206        HP            Notebook    15.6                     1366x768
#
#                                        Cpu  Ram                Memory  \
# 181             Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 246             Intel Core i5 7200U 2.5GHz    8               1TB HDD
# 1159            Intel Core i7 6600U 2.6GHz    8             512GB SSD
# 764               Intel Core i3 6006U 2GHz    4             500GB HDD
# 827               Intel Core i3 6006U 2GHz    4             500GB HDD
# 76              Intel Core i5 7200U 2.5GHz    8               2TB HDD
# 349             Intel Core i5 8250U 1.6GHz    8               1TB HDD
# 533   Intel Celeron Quad Core N3450 1.1GHz    4              32GB SSD
# 1236            Intel Core i7 6500U 2.5GHz    8             256GB SSD
# 148            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz    2             500GB HDD
# 99             Intel Core i7 7700HQ 2.8GHz   12  128GB SSD +  1TB HDD
# 139             Intel Core i5 7200U 2.5GHz    4             256GB SSD
# 810            Intel Core i7 7700HQ 2.8GHz   12               1TB HDD
# 1165           Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
# 860             Intel Core i5 7200U 2.5GHz    8               1TB HDD
# 1283            Intel Core i7 6500U 2.5GHz    4             500GB HDD
# 478             Intel Core i5 8250U 1.6GHz    8               1TB HDD
# 1168  Intel Celeron Dual Core N3060 1.6GHz    2    32GB Flash Storage
# 1206            Intel Core i5 7200U 2.5GHz    8             256GB SSD
#
#                              Gpu       OpSys  Weight        Price  \
# 181       Intel UHD Graphics 620  Windows 10    1.23   74538.7200
# 246        Intel HD Graphics 620  Windows 10    2.04   29783.5200
# 1159       Intel HD Graphics 520  Windows 10    1.48  108744.4800
# 764        Intel HD Graphics 520  Windows 10    1.65   45234.7200
# 827        Intel HD Graphics 520  Windows 10    1.76   31168.8000
# 76         Intel HD Graphics 620       No OS    2.20   27652.3200
# 349               AMD Radeon 530  Windows 10    1.90   35324.6400
# 533        Intel HD Graphics 500  Windows 10    1.20   19660.3200
# 1236       Intel HD Graphics 520   Windows 7    1.54  117119.5632
# 148      Nvidia GeForce GTX 1070  Windows 10    2.90  108105.1200
# 1292           Intel HD Graphics  Windows 10    2.20   20193.1200
# 99       Nvidia GeForce GTX 1050  Windows 10    2.62   66546.7200
# 139        Intel HD Graphics 620  Windows 10    1.32   37242.7200
# 810            AMD Radeon RX 580  Windows 10    3.74   93186.7200
# 1165  Nvidia GeForce GTX 1050 Ti  Windows 10    2.62   79813.4400
# 860        Intel HD Graphics 620  Windows 10    2.30   45323.1648
# 1283         Nvidia GeForce 920M  Windows 10    2.20   38378.6496
# 478               AMD Radeon 520  Windows 10    2.20   35964.0000
# 1168       Intel HD Graphics 400  Windows 10    1.44   13266.7200
# 1206       Intel HD Graphics 620  Windows 10    1.91   30849.1200
#
#       Touchscreen  Ips X_res Y_res
# 181             0    0  1920  1080
# 246             1    0  1366   768
# 1159            1    0  2560  1440
# 764             0    0  1366   768
# 827             0    0  1366   768
# 76              0    0  1920  1080
# 349             0    0  1920  1080
# 533             0    1  1920  1080
# 1236            0    0  2560  1440
# 148             0    0  1920  1080
# 1292            0    0  1366   768
# 99              0    1  1920  1080
# 139             0    1  1920  1080
# 810             0    1  1920  1080
# 1165            0    0  3840  2160
# 860             0    1  1920  1080
# 1283            0    0  1366   768
# 478             0    0  1920  1080
# 1168            0    0  1366   768
# 1206            0    0  1366   768

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# memory usage: 142.6+ KB

# %%
df.X_res = df.X_res.astype('int32')
df.Y_res = df.Y_res.astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# memory usage: 132.5+ KB

# %%
df.Company.dtype
# Out:
# dtype('O')

# %%
numerical = []
for col in df.columns:
    if df[col].dtypes !='object':
        numerical.append(col)
numerical
# Out:
# ['Inches', 'Ram', 'Weight', 'Price', 'Touchscreen', 'Ips', 'X_res', 'Y_res']

# %%
for col in numerical:
    if col!='Price':
        print(f"{col} : {df[col].corr(df.Price)}")
# Out:
# Inches : 0.06819666592963936
# Ram : 0.7430071352506953
# Weight : 0.21036980196834212
# Touchscreen : 0.19122646378672184
# Ips : 0.2522076196530881
# X_res : 0.556529328716981
# Y_res : 0.5528092198175052

# %%
df['PPI'] = (((df.X_res**2) + (df.Y_res**2))**0.5)/df.Inches

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    X_res  Y_res         PPI
# 0   2560   1600  226.983005
# 1   1440    900  127.677940
# 2   1920   1080  141.211998
# 3   2880   1800  220.534624
# 4   2560   1600  226.983005

# %%
df.PPI.astype('float')
# Out:
# 0       226.983005
# 1       127.677940
# 2       141.211998
# 3       220.534624
# 4       226.983005
#            ...
# 1298    157.350512
# 1299    276.053530
# 1300    111.935204
# 1301    100.454670
# 1302    100.454670
# Name: PPI, Length: 1303, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
#  15  PPI               1303 non-null   float64
# dtypes: float32(1), float64(3), int32(3), int64(2), object(7)
# memory usage: 142.6+ KB

# %%
df.drop('ScreenResolution', axis=1, inplace=True)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches                                   Cpu  Ram  \
# 338     Asus   Notebook    15.6  Intel Celeron Dual Core N3350 1.1GHz    4
# 812  Samsung  Ultrabook    13.3            Intel Core i5 7200U 2.5GHz    8
# 117     Dell   Notebook    15.6            Intel Core i7 8550U 1.8GHz    8
# 37      Dell   Notebook    17.3            Intel Core i5 8250U 1.6GHz    8
# 233     Dell   Notebook    14.0            Intel Core i5 7200U 2.5GHz    8
#
#                    Memory                    Gpu       OpSys  Weight  \
# 338               1TB HDD  Intel HD Graphics 500       Linux    2.00
# 812             256GB SSD  Intel HD Graphics 620  Windows 10    0.81
# 117  256GB SSD +  1TB HDD   Nvidia GeForce 940MX  Windows 10    2.16
# 37   128GB SSD +  1TB HDD         AMD Radeon 530  Windows 10    2.80
# 233             256GB SSD  Intel HD Graphics 620  Windows 10    1.60
#
#           Price  Touchscreen  Ips  X_res  Y_res         PPI
# 338  14651.4672            0    0   1366    768  100.454670
# 812  79866.7200            0    0   1920   1080  165.632118
# 117  60223.9824            0    1   1920   1080  141.211998
# 37   52161.1200            0    1   1920   1080  127.335675
# 233  45767.5200            0    0   1920   1080  157.350512

# %%
df.drop(columns=['Inches', 'X_res', 'Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df['Cpu_Name'] = df.Cpu.apply(lambda x : " ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu_Name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else :
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD processor'

# %%
df['Cpu_Brand'] = df.Cpu_Name.apply(fetch_processor)

# %%
df.sample(5)
# Out:
#      Company   TypeName                          Cpu  Ram  \
# 450       HP   Notebook   Intel Core i5 7200U 2.5GHz    8
# 917      MSI     Gaming  Intel Core i7 7700HQ 2.8GHz   16
# 1113      HP  Ultrabook   Intel Core i7 6500U 2.5GHz    8
# 1080  Lenovo  Ultrabook     Intel Core M 6Y75 1.2GHz    8
# 1007      HP  Ultrabook   Intel Core i7 6600U 2.6GHz    8
#
#                     Memory                         Gpu       OpSys  Weight  \
# 450              128GB SSD       Intel HD Graphics 620  Windows 10    1.91
# 917   256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10    2.70
# 1113             512GB SSD       Intel HD Graphics 520  Windows 10    1.16
# 1080             512GB SSD       Intel HD Graphics 515  Windows 10    0.99
# 1007             256GB SSD       Intel HD Graphics 520   Windows 7    1.43
#
#           Price  Touchscreen  Ips         PPI       Cpu_Name  \
# 450    31381.92            0    0  100.454670  Intel Core i5
# 917    85194.72            0    0  127.335675  Intel Core i7
# 1113  104908.32            0    0  165.632118  Intel Core i7
# 1080   74538.72            1    1  234.976765   Intel Core M
# 1007   77202.72            0    0  157.350512  Intel Core i7
#
#                   Cpu_Brand
# 450           Intel Core i5
# 917           Intel Core i7
# 1113          Intel Core i7
# 1080  Other Intel Processor
# 1007          Intel Core i7

# %%
df.Cpu_Brand.value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df.Cpu_Brand, y=df.Price, palette='viridis')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu_Name'],inplace=True)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Ram                Memory                      Gpu  \
# 520   Lenovo    Gaming    8  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060
# 873   Lenovo  Notebook    4             180GB SSD    Intel HD Graphics 620
# 828     Acer   Netbook    4    32GB Flash Storage    Intel HD Graphics 400
# 1148      HP  Notebook    8             256GB SSD    Intel HD Graphics 520
# 770     Dell  Notebook   16             256GB SSD       AMD Radeon R7 M445
#
#            OpSys  Weight       Price  Touchscreen  Ips         PPI  \
# 520   Windows 10    3.20  74538.7200            0    1  141.211998
# 873   Windows 10    1.44  39160.8000            0    1  165.632118
# 828    Chrome OS    1.35  18914.4000            0    1  135.094211
# 1148   Windows 7    1.88  84129.1200            0    0  141.211998
# 770   Windows 10    2.30  62938.0656            0    0  141.211998
#
#                   Cpu_Brand
# 520           Intel Core i7
# 873           Intel Core i3
# 828   Other Intel Processor
# 1148          Intel Core i5
# 770           Intel Core i7

# %%
df.Ram.value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df.Ram, y=df.Price, palette='viridis')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.Memory.value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '', regex=False)
df["Memory"] = df["Memory"].str.replace('TB', '000', regex=False)

new = df["Memory"].str.split("+", n=1, expand=True)
df["first"] = new[0].str.strip()
df["second"] = new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df["second"] = df["second"].fillna("0")

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].astype(str).str.replace(r'\D', '', regex=True)
df['second'] = df['second'].astype(str).str.replace(r'\D', '', regex=True)

df['first'] = df['first'].replace('', '0')
df['second'] = df['second'].replace('', '0')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"] = df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"]
df["SSD"] = df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"]
df["Hybrid"] = df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"]
df["Flash_Storage"] = df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"]

df.drop(columns=[
    'first', 'second',
    'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
    'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'
], inplace=True)

# %%
df.sample(6)
# Out:
#      Company  TypeName  Ram               Memory                      Gpu  \
# 149     Acer  Notebook    4             1000 HDD    Intel HD Graphics 520
# 456     Dell  Notebook    8             1000 HDD  Nvidia GeForce GTX 1060
# 237     Asus  Notebook    4  128 SSD +  1000 HDD       AMD Radeon R5 M430
# 511     Acer  Notebook    4              500 HDD     Nvidia GeForce 940MX
# 357     Dell    Gaming    8             1000 HDD  Nvidia GeForce GTX 1050
# 1129      HP    Gaming    8  128 SSD +  1000 HDD  Nvidia GeForce GTX 1060
#
#            OpSys  Weight      Price  Touchscreen  Ips         PPI  \
# 149   Windows 10    2.10   23816.16            0    0  100.454670
# 456   Windows 10    4.42  109010.88            0    1  127.335675
# 237   Windows 10    2.20   30636.00            0    0  141.211998
# 511   Windows 10    2.20   34045.92            0    0  141.211998
# 357   Windows 10    2.65   53226.72            0    0  141.211998
# 1129  Windows 10    3.35   60153.12            0    1  127.335675
#
#           Cpu_Brand   HDD  SSD  Hybrid  Flash_Storage
# 149   Intel Core i3  1000    0       0              0
# 456   Intel Core i7  1000    0       0              0
# 237   AMD processor  1000  128       0              0
# 511   Intel Core i7   500    0       0              0
# 357   Intel Core i5  1000    0       0              0
# 1129  Intel Core i5  1000  128       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         PPI      Cpu_Brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Ram            1303 non-null   int32
#  3   Gpu            1303 non-null   object
#  4   OpSys          1303 non-null   object
#  5   Weight         1303 non-null   float32
#  6   Price          1303 non-null   float64
#  7   Touchscreen    1303 non-null   int64
#  8   Ips            1303 non-null   int64
#  9   PPI            1303 non-null   float64
#  10  Cpu_Brand      1303 non-null   object
#  11  HDD            1303 non-null   int64
#  12  SSD            1303 non-null   int64
#  13  Hybrid         1303 non-null   int64
#  14  Flash_Storage  1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(6), object(5)
# memory usage: 142.6+ KB

# %%
numerical = []
for col in df.columns:
    if df[col].dtypes !='object':
        numerical.append(col)
numerical
# Out:
# ['Ram',
#  'Weight',
#  'Price',
#  'Touchscreen',
#  'Ips',
#  'PPI',
#  'HDD',
#  'SSD',
#  'Hybrid',
#  'Flash_Storage']

# %%
for col in numerical:
    if col!='Price':
        print(f"{col} : {df[col].corr(df.Price)}")
# Out:
# Ram : 0.7430071352506953
# Weight : 0.21036980196834212
# Touchscreen : 0.19122646378672184
# Ips : 0.2522076196530881
# PPI : 0.4734873076608601
# HDD : -0.09644098036676853
# SSD : 0.6707991100735979
# Hybrid : 0.007989384746104713
# Flash_Storage : -0.04051115407692772

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         PPI      Cpu_Brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df.Gpu.value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_Brand'] = df.Gpu.apply(lambda x : x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         PPI      Cpu_Brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu_Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df.Gpu_Brand.value_counts()
# Out:
# Gpu_Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df.Gpu_Brand !='ARM']

# %%
df.Gpu_Brand.value_counts()
# Out:
# Gpu_Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu_Brand'],y=df['Price'],estimator=np.median, palette='rainbow')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu_Brand  HDD  SSD Gpu_Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df.OpSys.value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'], palette='rainbow')
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df.OpSys = df.OpSys.apply(cat_os)

# %%
df.sample(10)
# Out:
#      Company   TypeName  Ram               OpSys  Weight        Price  \
# 788     Acer     Gaming   16             Windows    4.20  122490.7200
# 762   Google  Ultrabook    8  Others/No OS/Linux    1.10   83063.5200
# 627   Lenovo   Notebook    4  Others/No OS/Linux    2.20   24935.0400
# 180     Dell   Notebook   16  Others/No OS/Linux    2.02   55890.7200
# 1036      HP   Notebook    4             Windows    2.04   39533.7600
# 927       HP   Notebook    8             Windows    2.31   62071.2000
# 371     Acer   Notebook    4             Windows    2.10   22697.2800
# 969   Lenovo   Notebook    6             Windows    2.40   37029.6000
# 478     Dell   Notebook    8             Windows    2.20   35964.0000
# 1232    Dell   Notebook    8             Windows    2.30   24988.8528
#
#       Touchscreen  Ips         PPI      Cpu_Brand   HDD  SSD Gpu_Brand
# 788             0    1  127.335675  Intel Core i7  1000  256    Nvidia
# 762             1    0  234.507400  Intel Core i5     0  256     Intel
# 627             0    0  141.211998  Intel Core i5     0  128     Intel
# 180             0    0  141.211998  Intel Core i7  2000  256       AMD
# 1036            0    0  100.454670  Intel Core i5   500    0     Intel
# 927             0    0  141.211998  Intel Core i5     0  256     Intel
# 371             0    0  100.454670  AMD processor     0  128       AMD
# 969             0    0  141.211998  Intel Core i5     0  256    Nvidia
# 478             0    0  141.211998  Intel Core i5  1000    0       AMD
# 1232            1    0  100.454670  Intel Core i3  1000    0     Intel

# %%
df.rename(columns = {'OpSys' : 'Os'}, inplace=True)

# %%
df.sample(5)
# Out:
#       Company     TypeName  Ram       Os  Weight        Price  Touchscreen  \
# 892   Samsung    Ultrabook    8  Windows    1.17   90522.7200            0
# 539    Lenovo     Notebook    8  Windows    1.87   45767.5200            0
# 410    Lenovo  Workstation    8  Windows    2.67  102564.0000            0
# 1101     Dell    Ultrabook    4  Windows    1.50   62176.1616            0
# 972      Dell       Gaming   32  Windows    4.42  149184.0000            0
#
#       Ips         PPI      Cpu_Brand   HDD  SSD Gpu_Brand
# 892     0  146.860478  Intel Core i7     0  256     Intel
# 539     1  157.350512  Intel Core i7     0  256    Nvidia
# 410     0  141.211998  Intel Core i7     0  512    Nvidia
# 1101    0  125.367428  Intel Core i3     0  128     Intel
# 972     0  127.335675  Intel Core i7  1000  256    Nvidia

# %%
sns.barplot(x=df['Os'],y=df['Price'], palette='rainbow')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.histplot(df.Weight, kde=True)
plt.show()

# %%
sns.scatterplot(x=df.Weight, y=df.Price)
plt.show()

# %%
numerical = []
for col in df.columns:
    if df[col].dtypes !='object':
        numerical.append(col)
numerical
# Out:
# ['Ram', 'Weight', 'Price', 'Touchscreen', 'Ips', 'PPI', 'HDD', 'SSD']

# %%
for col in numerical:
    if col!='Price':
        print(f"{col} : {df[col].corr(df.Price)}")
# Out:
# Ram : 0.7429050080846193
# Weight : 0.20986692455314296
# Touchscreen : 0.19291700874092949
# Ips : 0.25331954754593133
# PPI : 0.4753684169655958
# HDD : -0.09689129776872671
# SSD : 0.6706598015928436

# %%
df[numerical].corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# PPI            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(df[numerical].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(df.Price, kde=True)
plt.show()

# %%
sns.histplot(np.log1p(df.Price), kde=True)
plt.show()

# %%
X = df.drop(columns=['Price'])

# %%
y = np.log(df.Price)

# %%
X
# Out:
#      Company            TypeName  Ram                  Os  Weight  \
# 0      Apple           Ultrabook    8                 Mac    1.37
# 1      Apple           Ultrabook    8                 Mac    1.34
# 2         HP            Notebook    8  Others/No OS/Linux    1.86
# 3      Apple           Ultrabook   16                 Mac    1.83
# 4      Apple           Ultrabook    8                 Mac    1.37
# ...      ...                 ...  ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    4             Windows    1.80
# 1299  Lenovo  2 in 1 Convertible   16             Windows    1.30
# 1300  Lenovo            Notebook    2             Windows    1.50
# 1301      HP            Notebook    6             Windows    2.19
# 1302    Asus            Notebook    4             Windows    2.20
#
#       Touchscreen  Ips         PPI              Cpu_Brand   HDD  SSD Gpu_Brand
# 0               0    1  226.983005          Intel Core i5     0  128     Intel
# 1               0    0  127.677940          Intel Core i5     0    0     Intel
# 2               0    0  141.211998          Intel Core i5     0  256     Intel
# 3               0    1  220.534624          Intel Core i7     0  512       AMD
# 4               0    1  226.983005          Intel Core i5     0  256     Intel
# ...           ...  ...         ...                    ...   ...  ...       ...
# 1298            1    1  157.350512          Intel Core i7     0  128     Intel
# 1299            1    1  276.053530          Intel Core i7     0  512     Intel
# 1300            0    0  111.935204  Other Intel Processor     0    0     Intel
# 1301            0    0  100.454670          Intel Core i7  1000    0       AMD
# 1302            0    0  100.454670  Other Intel Processor   500    0     Intel
#
# [1302 rows x 12 columns]

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 2)

# %%
X_train
# Out:
#      Company   TypeName  Ram                  Os  Weight  Touchscreen  Ips  \
# 91      Acer   Notebook    8             Windows    2.20            0    0
# 863   Lenovo     Gaming    8  Others/No OS/Linux    2.50            0    1
# 552     Dell     Gaming   16             Windows    4.42            0    1
# 967       HP   Notebook    4             Windows    2.04            0    0
# 365       HP   Notebook    8             Windows    2.04            0    0
# ...      ...        ...  ...                 ...     ...          ...  ...
# 466     Acer   Notebook    4             Windows    2.20            0    0
# 299     Asus  Ultrabook   16             Windows    1.63            0    0
# 493     Acer   Notebook    8             Windows    2.20            0    0
# 527   Lenovo   Notebook    8  Others/No OS/Linux    2.20            0    0
# 1193   Apple  Ultrabook    8                 Mac    0.92            0    1
#
#              PPI              Cpu_Brand   HDD  SSD Gpu_Brand
# 91    141.211998          Intel Core i7  1000    0    Nvidia
# 863   141.211998          Intel Core i5  1000    0    Nvidia
# 552   127.335675          Intel Core i7  1000  256    Nvidia
# 967   141.211998          Intel Core i3   500    0     Intel
# 365   100.454670  Other Intel Processor  2000    0     Intel
# ...          ...                    ...   ...  ...       ...
# 466   100.454670          Intel Core i3   500    0    Nvidia
# 299   141.211998          Intel Core i7     0  512    Nvidia
# 493   100.454670          AMD processor  1000    0       AMD
# 527   100.454670          Intel Core i3  2000    0    Nvidia
# 1193  226.415547  Other Intel Processor     0    0     Intel
#
# [1041 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_absolute_error

# %%
df.head()
# Out:
#   Company   TypeName  Ram                  Os  Weight        Price  \
# 0   Apple  Ultrabook    8                 Mac    1.37   71378.6832
# 1   Apple  Ultrabook    8                 Mac    1.34   47895.5232
# 2      HP   Notebook    8  Others/No OS/Linux    1.86   30636.0000
# 3   Apple  Ultrabook   16                 Mac    1.83  135195.3360
# 4   Apple  Ultrabook    8                 Mac    1.37   96095.8080
#
#    Touchscreen  Ips         PPI      Cpu_Brand  HDD  SSD Gpu_Brand
# 0            0    1  226.983005  Intel Core i5    0  128     Intel
# 1            0    0  127.677940  Intel Core i5    0    0     Intel
# 2            0    0  141.211998  Intel Core i5    0  256     Intel
# 3            0    1  220.534624  Intel Core i7    0  512       AMD
# 4            0    1  226.983005  Intel Core i5    0  256     Intel

# %%
X_train.head()
# Out:
#     Company  TypeName  Ram                  Os  Weight  Touchscreen  Ips  \
# 91     Acer  Notebook    8             Windows    2.20            0    0
# 863  Lenovo    Gaming    8  Others/No OS/Linux    2.50            0    1
# 552    Dell    Gaming   16             Windows    4.42            0    1
# 967      HP  Notebook    4             Windows    2.04            0    0
# 365      HP  Notebook    8             Windows    2.04            0    0
#
#             PPI              Cpu_Brand   HDD  SSD Gpu_Brand
# 91   141.211998          Intel Core i7  1000    0    Nvidia
# 863  141.211998          Intel Core i5  1000    0    Nvidia
# 552  127.335675          Intel Core i7  1000  256    Nvidia
# 967  141.211998          Intel Core i3   500    0     Intel
# 365  100.454670  Other Intel Processor  2000    0     Intel

# %% [markdown]
# ## Linear Regression

# %%
step1 = ColumnTransformer(transformers = [
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,3,8,11])
], remainder='passthrough')

step2 = LinearRegression()

# %%
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 3, 8, 11])])),
#                 ('step2', LinearRegression())])

# %%
y_pred = pipe.predict(X_test)

# %%
print('R2 score : ', r2_score(y_test,y_pred))
# Out:
# R2 score :  0.8002405966123198

# %%
print('MAE : ', mean_absolute_error(y_test,y_pred))
# Out:
# MAE :  0.20453995815618412

# %% [markdown]
# ## Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8025355126649513
# MAE 0.20379724333815155

# %% [markdown]
# ## Lasso

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7980041380217919
# MAE 0.2060401867431043

# %% [markdown]
# ## KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.787987231643963
# MAE 0.19769269025484218

# %% [markdown]
# ## Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=9)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7981424947319353
# MAE 0.19527592823285447

# %% [markdown]
# ## SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7767571730295864
# MAE 0.203723502389996

# %% [markdown]
# ## Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8632978656560094
# MAE 0.16722723335164247

# %% [markdown]
# ## ExtraTrees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15,
                           bootstrap = True)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8693032312184191
# MAE 0.16485575280464862

# %% [markdown]
# ## AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7723514117696216
# MAE 0.23088113060882645

# %% [markdown]
# ## Gradient Boosting

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8637008048899861
# MAE 0.16373558055847612

# %% [markdown]
# ## Xgboost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8533066956579289
# MAE 0.16916476273326114

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10, bootstrap = True)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8768227952805805
# MAE 0.1594955848183708

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8725631178711339
# MAE 0.1622188429335362

# %%
import optuna

def objective(trial):
   
    model_name = trial.suggest_categorical("model", [
        "LinearRegression", "Ridge", "Lasso", "KNN", "DecisionTree", "RandomForest",
        "ExtraTrees", "SVR", "GradientBoosting", "XGBoost"
    ])

   
    step1 = ColumnTransformer(transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,3,8,11])
    ], remainder='passthrough')


    if model_name == "LinearRegression":
        model = LinearRegression()

    elif model_name == "Ridge":
        alpha = trial.suggest_float("ridge_alpha", 0.01, 100.0, log=True)
        model = Ridge(alpha=alpha)

    elif model_name == "Lasso":
        alpha = trial.suggest_float("lasso_alpha", 1e-5, 1e-1, log=True)
        model = Lasso(alpha=alpha)

    elif model_name == "KNN":
        n_neighbors = trial.suggest_int("knn_n", 1, 15)
        model = KNeighborsRegressor(n_neighbors=n_neighbors)

    elif model_name == "DecisionTree":
        max_depth = trial.suggest_int("dt_depth", 3, 20)
        model = DecisionTreeRegressor(max_depth=max_depth)

    elif model_name == "RandomForest":
        n_estimators = trial.suggest_int("rf_estimators", 50, 500)
        max_depth = trial.suggest_int("rf_depth", 5, 20)
        max_features = trial.suggest_float("rf_features", 0.2, 1.0)
        max_samples = trial.suggest_float("rf_samples", 0.2, 1.0)
        model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth,
                                      max_features=max_features, max_samples=max_samples,
                                      random_state=3)

    elif model_name == "ExtraTrees":
        n_estimators = trial.suggest_int("et_estimators", 50, 500)
        max_depth = trial.suggest_int("et_depth", 5, 20)
        max_features = trial.suggest_float("et_features", 0.2, 1.0)
        max_samples = trial.suggest_float("et_samples", 0.2, 1.0)
        model = ExtraTreesRegressor(n_estimators=n_estimators, max_depth=max_depth,
                                    max_features=max_features, max_samples=max_samples,
                                    bootstrap = True, random_state=3)

    elif model_name == "SVR":
        C = trial.suggest_float("svr_C", 1, 10000, log=True)
        epsilon = trial.suggest_float("svr_epsilon", 0.01, 1.0)
        model = SVR(kernel='rbf', C=C, epsilon=epsilon)

    elif model_name == "GradientBoosting":
        n_estimators = trial.suggest_int("gbdt_estimators", 50, 500)
        max_depth = trial.suggest_int("gbdt_depth", 3, 10)
        learning_rate = trial.suggest_float("gbdt_lr", 0.01, 0.5)
        model = GradientBoostingRegressor(n_estimators=n_estimators, max_depth=max_depth,
                                          learning_rate=learning_rate)

    elif model_name == "XGBoost":
        n_estimators = trial.suggest_int("xgb_estimators", 25, 100)
        learning_rate = trial.suggest_float("xgb_lr", 0.01, 0.5)
        max_depth = trial.suggest_int("xgb_depth", 3, 10)
        model = XGBRegressor(n_estimators=n_estimators, learning_rate=learning_rate,
                             max_depth=max_depth, verbosity=0)


    pipe = Pipeline([
        ('step1', step1),
        ('step2', model)
    ])

 
    pipe.fit(X_train, y_train)


    y_pred = pipe.predict(X_test)
    score = r2_score(y_test, y_pred)  
    return score


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50, n_jobs=-1)


print("\nBest Model & Hyperparameters:")
print(study.best_trial)
# Out:
# [I 2025-07-25 21:30:18,209] A new study created in memory with name: no-name-80555097-67c7-48ac-ad2f-deeed996a8b9
# [I 2025-07-25 21:30:18,396] Trial 0 finished with value: 0.7870485571639916 and parameters: {'model': 'Ridge', 'ridge_alpha': 56.94582467693572}. Best is trial 0 with value: 0.7870485571639916.
# [I 2025-07-25 21:30:18,457] Trial 2 finished with value: 0.7712878683177146 and parameters: {'model': 'DecisionTree', 'dt_depth': 13}. Best is trial 0 with value: 0.7870485571639916.
# [I 2025-07-25 21:30:18,537] Trial 5 finished with value: 0.7867562047547709 and parameters: {'model': 'DecisionTree', 'dt_depth': 10}. Best is trial 0 with value: 0.7870485571639916.
# [I 2025-07-25 21:30:18,569] Trial 3 finished with value: 0.7393957128917075 and parameters: {'model': 'KNN', 'knn_n': 15}. Best is trial 0 with value: 0.7870485571639916.
# [I 2025-07-25 21:30:18,594] Trial 7 finished with value: 0.8002405966122906 and parameters: {'model': 'LinearRegression'}. Best is trial 7 with value: 0.8002405966122906.
# [I 2025-07-25 21:30:18,675] Trial 6 finished with value: 0.596595431070752 and parameters: {'model': 'SVR', 'svr_C': 4.257625565970317, 'svr_epsilon': 0.7000939173817291}. Best is trial 7 with value: 0.8002405966122906.
# [I 2025-07-25 21:30:18,682] Trial 10 finished with value: 0.8036325682795712 and parameters: {'model': 'DecisionTree', 'dt_depth': 8}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:18,700] Trial 11 finished with value: 0.7994055071034418 and parameters: {'model': 'Lasso', 'lasso_alpha': 0.0008091234215333337}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:18,781] Trial 9 finished with value: 0.802346620197107 and parameters: {'model': 'Lasso', 'lasso_alpha': 0.00037094868055276536}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:18,903] Trial 18 finished with value: 0.8002405966123198 and parameters: {'model': 'LinearRegression'}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:19,041] Trial 19 finished with value: 0.8004972612236396 and parameters: {'model': 'Ridge', 'ridge_alpha': 0.05590414375595}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:19,163] Trial 16 finished with value: 0.8027227892171755 and parameters: {'model': 'Ridge', 'ridge_alpha': 1.5309331353142204}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:19,214] Trial 21 finished with value: 0.8029685348032055 and parameters: {'model': 'Ridge', 'ridge_alpha': 4.078805716276603}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:19,255] Trial 22 finished with value: 0.7907494838176994 and parameters: {'model': 'Lasso', 'lasso_alpha': 0.004269825873546556}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:19,259] Trial 24 finished with value: 0.8012149243126747 and parameters: {'model': 'Ridge', 'ridge_alpha': 0.2573242846296444}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:19,980] Trial 27 finished with value: 0.7467094801740465 and parameters: {'model': 'KNN', 'knn_n': 13}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:21,118] Trial 28 finished with value: 0.7973445985652661 and parameters: {'model': 'Ridge', 'ridge_alpha': 29.943739920880326}. Best is trial 10 with value: 0.8036325682795712.
# [I 2025-07-25 21:30:25,124] Trial 33 finished with value: 0.8711574668917229 and parameters: {'model': 'XGBoost', 'xgb_estimators': 62, 'xgb_lr': 0.4801032950174757, 'xgb_depth': 3}. Best is trial 33 with value: 0.8711574668917229.
# [I 2025-07-25 21:30:25,471] Trial 12 finished with value: 0.8137592822545123 and parameters: {'model': 'ExtraTrees', 'et_estimators': 73, 'et_depth': 5, 'et_features': 0.44877099224227096, 'et_samples': 0.7150706339612309}. Best is trial 33 with value: 0.8711574668917229.
# [I 2025-07-25 21:30:25,955] Trial 23 finished with value: 0.8749651590684662 and parameters: {'model': 'XGBoost', 'xgb_estimators': 74, 'xgb_lr': 0.4128413236451187, 'xgb_depth': 3}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:26,444] Trial 36 finished with value: 0.8708841430271055 and parameters: {'model': 'ExtraTrees', 'et_estimators': 73, 'et_depth': 17, 'et_features': 0.474766494579511, 'et_samples': 0.8765223932204491}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:26,979] Trial 4 finished with value: 0.8564462358936544 and parameters: {'model': 'RandomForest', 'rf_estimators': 103, 'rf_depth': 17, 'rf_features': 0.8382060245687912, 'rf_samples': 0.21652453235044888}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:27,070] Trial 34 finished with value: 0.8196901578021353 and parameters: {'model': 'XGBoost', 'xgb_estimators': 67, 'xgb_lr': 0.4688475032851305, 'xgb_depth': 10}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:27,155] Trial 31 finished with value: 0.8417861866239034 and parameters: {'model': 'XGBoost', 'xgb_estimators': 83, 'xgb_lr': 0.2986973561767217, 'xgb_depth': 8}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:27,438] Trial 32 finished with value: 0.8435332541186245 and parameters: {'model': 'XGBoost', 'xgb_estimators': 74, 'xgb_lr': 0.29832462010528693, 'xgb_depth': 10}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:28,754] Trial 20 finished with value: 0.8729668598775493 and parameters: {'model': 'RandomForest', 'rf_estimators': 113, 'rf_depth': 13, 'rf_features': 0.41350264536201276, 'rf_samples': 0.9200934593567238}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:29,307] Trial 37 finished with value: 0.8580387564346198 and parameters: {'model': 'ExtraTrees', 'et_estimators': 136, 'et_depth': 10, 'et_features': 0.3086742971577729, 'et_samples': 0.2066887939440173}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:29,843] Trial 17 finished with value: 0.8224327512126324 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 170, 'gbdt_depth': 10, 'gbdt_lr': 0.46982760749275043}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:29,913] Trial 41 finished with value: 0.8676069058545858 and parameters: {'model': 'XGBoost', 'xgb_estimators': 61, 'xgb_lr': 0.4810984784876173, 'xgb_depth': 3}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:30,362] Trial 47 finished with value: 0.8713189258524427 and parameters: {'model': 'XGBoost', 'xgb_estimators': 37, 'xgb_lr': 0.48658321498375806, 'xgb_depth': 3}. Best is trial 23 with value: 0.8749651590684662.
# [I 2025-07-25 21:30:30,414] Trial 29 finished with value: 0.8788705852316971 and parameters: {'model': 'RandomForest', 'rf_estimators': 141, 'rf_depth': 16, 'rf_features': 0.3779756494153117, 'rf_samples': 0.7858414542339094}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:30,566] Trial 42 finished with value: 0.8143232811072891 and parameters: {'model': 'ExtraTrees', 'et_estimators': 65, 'et_depth': 5, 'et_features': 0.4303448594796291, 'et_samples': 0.7607669755067614}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:30,818] Trial 48 finished with value: 0.8449316418989922 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 62, 'gbdt_depth': 9, 'gbdt_lr': 0.04360859642054987}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:31,068] Trial 43 finished with value: 0.8707008678669143 and parameters: {'model': 'XGBoost', 'xgb_estimators': 68, 'xgb_lr': 0.47056848343835755, 'xgb_depth': 3}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:31,127] Trial 44 finished with value: 0.8681921801846948 and parameters: {'model': 'XGBoost', 'xgb_estimators': 72, 'xgb_lr': 0.4842995037976989, 'xgb_depth': 3}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:31,346] Trial 46 finished with value: 0.8683859586259961 and parameters: {'model': 'XGBoost', 'xgb_estimators': 65, 'xgb_lr': 0.4512204190141143, 'xgb_depth': 3}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:31,543] Trial 39 finished with value: 0.8511440270801051 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 210, 'gbdt_depth': 3, 'gbdt_lr': 0.49216926627593116}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:31,646] Trial 45 finished with value: 0.86984696203404 and parameters: {'model': 'XGBoost', 'xgb_estimators': 69, 'xgb_lr': 0.4847389346103745, 'xgb_depth': 3}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:32,750] Trial 8 finished with value: 0.8321694668118402 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 304, 'gbdt_depth': 5, 'gbdt_lr': 0.3292691967517037}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:33,158] Trial 1 finished with value: 0.8575291847544703 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 320, 'gbdt_depth': 3, 'gbdt_lr': 0.18930107581270772}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:33,222] Trial 35 finished with value: 0.855191777824668 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 247, 'gbdt_depth': 7, 'gbdt_lr': 0.08694475148205413}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:33,481] Trial 26 finished with value: 0.8315134660346503 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 255, 'gbdt_depth': 9, 'gbdt_lr': 0.07152425581912636}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:33,739] Trial 40 finished with value: 0.8531694910559915 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 256, 'gbdt_depth': 8, 'gbdt_lr': 0.023260537810634807}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:34,452] Trial 13 finished with value: 0.878103261285881 and parameters: {'model': 'RandomForest', 'rf_estimators': 280, 'rf_depth': 20, 'rf_features': 0.3649218391001068, 'rf_samples': 0.81175346461992}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:34,638] Trial 38 finished with value: 0.8517887883021245 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 301, 'gbdt_depth': 7, 'gbdt_lr': 0.055533165106149834}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:34,744] Trial 14 finished with value: 0.8232120215390304 and parameters: {'model': 'GradientBoosting', 'gbdt_estimators': 351, 'gbdt_depth': 5, 'gbdt_lr': 0.34050571610004426}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:34,827] Trial 49 finished with value: 0.8725786198007919 and parameters: {'model': 'RandomForest', 'rf_estimators': 183, 'rf_depth': 8, 'rf_features': 0.33608584106126266, 'rf_samples': 0.9970003686877221}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:35,120] Trial 30 finished with value: 0.8721645159364994 and parameters: {'model': 'ExtraTrees', 'et_estimators': 327, 'et_depth': 20, 'et_features': 0.9147041650448158, 'et_samples': 0.6051676467130988}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:35,578] Trial 15 finished with value: 0.870555653620974 and parameters: {'model': 'RandomForest', 'rf_estimators': 450, 'rf_depth': 8, 'rf_features': 0.39752528166692613, 'rf_samples': 0.47668654190771154}. Best is trial 29 with value: 0.8788705852316971.
# [I 2025-07-25 21:30:35,702] Trial 25 finished with value: 0.8679505535278189 and parameters: {'model': 'ExtraTrees', 'et_estimators': 465, 'et_depth': 8, 'et_features': 0.7052450684357441, 'et_samples': 0.7720584948605338}. Best is trial 29 with value: 0.8788705852316971.
# Best Model & Hyperparameters:
# FrozenTrial(number=29, state=1, values=[0.8788705852316971], datetime_start=datetime.datetime(2025, 7, 25, 21, 30, 18, 962612), datetime_complete=datetime.datetime(2025, 7, 25, 21, 30, 30, 414121), params={'model': 'RandomForest', 'rf_estimators': 141, 'rf_depth': 16, 'rf_features': 0.3779756494153117, 'rf_samples': 0.7858414542339094}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'model': CategoricalDistribution(choices=('LinearRegression', 'Ridge', 'Lasso', 'KNN', 'DecisionTree', 'RandomForest', 'ExtraTrees', 'SVR', 'GradientBoosting', 'XGBoost')), 'rf_estimators': IntDistribution(high=500, log=False, low=50, step=1), 'rf_depth': IntDistribution(high=20, log=False, low=5, step=1), 'rf_features': FloatDistribution(high=1.0, log=False, low=0.2, step=None), 'rf_samples': FloatDistribution(high=1.0, log=False, low=0.2, step=None)}, trial_id=29, value=None)

# %%
best_trial = study.best_trial
print("Best trial parameters:", best_trial.params)
print("Best trial r2_score:", best_trial.value)
# Out:
# Best trial parameters: {'model': 'RandomForest', 'rf_estimators': 141, 'rf_depth': 16, 'rf_features': 0.3779756494153117, 'rf_samples': 0.7858414542339094}
# Best trial r2_score: 0.8788705852316971

# %%
st = study.trials_dataframe()

# %%
st.head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.787049 2025-07-25 21:30:18.215871 2025-07-25 21:30:18.396507
# 1       1  0.857529 2025-07-25 21:30:18.231953 2025-07-25 21:30:33.158461
# 2       2  0.771288 2025-07-25 21:30:18.237961 2025-07-25 21:30:18.457026
# 3       3  0.739396 2025-07-25 21:30:18.255034 2025-07-25 21:30:18.569249
# 4       4  0.856446 2025-07-25 21:30:18.262034 2025-07-25 21:30:26.979503
#
#                 duration  params_dt_depth  params_et_depth  \
# 0 0 days 00:00:00.180636              NaN              NaN
# 1 0 days 00:00:14.926508              NaN              NaN
# 2 0 days 00:00:00.219065             13.0              NaN
# 3 0 days 00:00:00.314215              NaN              NaN
# 4 0 days 00:00:08.717469              NaN              NaN
#
#    params_et_estimators  params_et_features  params_et_samples  ...  \
# 0                   NaN                 NaN                NaN  ...
# 1                   NaN                 NaN                NaN  ...
# 2                   NaN                 NaN                NaN  ...
# 3                   NaN                 NaN                NaN  ...
# 4                   NaN                 NaN                NaN  ...
#
#    params_rf_estimators  params_rf_features  params_rf_samples  \
# 0                   NaN                 NaN                NaN
# 1                   NaN                 NaN                NaN
# 2                   NaN                 NaN                NaN
# 3                   NaN                 NaN                NaN
# 4                 103.0            0.838206           0.216525
#
#    params_ridge_alpha  params_svr_C params_svr_epsilon  params_xgb_depth  \
# 0           56.945825           NaN                NaN               NaN
# 1                 NaN           NaN                NaN               NaN
# 2                 NaN           NaN                NaN               NaN
# 3                 NaN           NaN                NaN               NaN
# 4                 NaN           NaN                NaN               NaN
#
#    params_xgb_estimators  params_xgb_lr     state
# 0                    NaN            NaN  COMPLETE
# 1                    NaN            NaN  COMPLETE
# 2                    NaN            NaN  COMPLETE
# 3                    NaN            NaN  COMPLETE
# 4                    NaN            NaN  COMPLETE
#
# [5 rows x 27 columns]

# %%
st.columns
# Out:
# Index(['number', 'value', 'datetime_start', 'datetime_complete', 'duration',
#        'params_dt_depth', 'params_et_depth', 'params_et_estimators',
#        'params_et_features', 'params_et_samples', 'params_gbdt_depth',
#        'params_gbdt_estimators', 'params_gbdt_lr', 'params_knn_n',
#        'params_lasso_alpha', 'params_model', 'params_rf_depth',
#        'params_rf_estimators', 'params_rf_features', 'params_rf_samples',
#        'params_ridge_alpha', 'params_svr_C', 'params_svr_epsilon',
#        'params_xgb_depth', 'params_xgb_estimators', 'params_xgb_lr', 'state'],
#       dtype='object')

# %%
study.trials_dataframe()['params_model'].value_counts()
# Out:
# params_model
# XGBoost             11
# GradientBoosting    10
# Ridge                6
# RandomForest         6
# ExtraTrees           6
# DecisionTree         3
# Lasso                3
# KNN                  2
# LinearRegression     2
# SVR                  1
# Name: count, dtype: int64

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,3,8,11])
], remainder='passthrough')

best_model = RandomForestRegressor(
    n_estimators=250,
    max_depth=19,
    max_features=0.25676,
    max_samples=0.44019,
    random_state=3
)

pipe = Pipeline([
    ('step1', step1),
    ('step2', best_model)
])

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 3, 8, 11])])),
#                 ('step2',
#                  RandomForestRegressor(max_depth=19, max_features=0.25676,
#                                        max_samples=0.44019, n_estimators=250,
#                                        random_state=3))])

# %%
y_pred = pipe.predict(X_test)

# %%
print("Final R²:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# Final R²: 0.881575648582357
# MAE: 0.15846645797052528

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(pipe, X_train, y_train, cv=5, scoring='r2')
print("CV R² Mean:", cv_scores.mean())
print("CV R² Std Dev:", cv_scores.std())
# Out:
# CV R² Mean: 0.8668059522446395
# CV R² Std Dev: 0.024194098745352367

# %% [markdown]
# ## Exporting the model

# %%
import pickle

# %%
df.head()
# Out:
#   Company   TypeName  Ram                  Os  Weight        Price  \
# 0   Apple  Ultrabook    8                 Mac    1.37   71378.6832
# 1   Apple  Ultrabook    8                 Mac    1.34   47895.5232
# 2      HP   Notebook    8  Others/No OS/Linux    1.86   30636.0000
# 3   Apple  Ultrabook   16                 Mac    1.83  135195.3360
# 4   Apple  Ultrabook    8                 Mac    1.37   96095.8080
#
#    Touchscreen  Ips         PPI      Cpu_Brand  HDD  SSD Gpu_Brand
# 0            0    1  226.983005  Intel Core i5    0  128     Intel
# 1            0    0  127.677940  Intel Core i5    0    0     Intel
# 2            0    0  141.211998  Intel Core i5    0  256     Intel
# 3            0    1  220.534624  Intel Core i7    0  512       AMD
# 4            0    1  226.983005  Intel Core i5    0  256     Intel

# %%
pickle.dump(df,open('df.pkl', 'wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
